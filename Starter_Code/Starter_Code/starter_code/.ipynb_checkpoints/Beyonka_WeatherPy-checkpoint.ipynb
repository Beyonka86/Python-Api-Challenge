# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create an empty list to hold the weather data.
city_data = []

# Define an empty list to fetch the weather data for each city
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
country_list = []
date_list = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
counter = 0

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + cities[i]
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_list.append(city_weather['name'])
        lat_list.append(city_weather['coord']['lat'])
        lng_list.append(city_weather['coord']['lon'])
        max_temp_list.append(city_weather['main']['temp_max'])
        humidity_list.append(city_weather['main']['humidity'])
        cloudiness_list.append(city_weather['clouds']['all'])
        windspeed_list.append(city_weather['wind']['speed'])
        date_list.append(city_weather['dt'])
        country_list.append(city_weather['sys']['country'])


             # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        # city_lat = city_weather["coord"]["lat"]
        # city_lng = city_weather["coord"]["lon"]
        # city_max_temp = city_weather["main"]["temp_max"]
        # city_humidity = city_weather["main"]["humidity"]
        # city_clouds = city_weather["clouds"]["all"]
        # city_wind = city_weather["wind"]["speed"]
        # city_country = city_weather["sys"]["country"]
        # city_date = city_weather["dt"]

    
        # Append the City information into city_data list
        city_data.append({"City": city_list, 
                          "Lat": lat_list, 
                          "Lng": lng_list, 
                          "Max Temp": max_temp_list,
                          "Humidity": humidity_list,
                          "Cloudiness": cloudiness_list,
                          "Wind Speed": windspeed_list,
                          "Country": country_list,
                          "Date": date_list})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kutum
# Processing Record 2 of Set 1 | nogliki
# Processing Record 3 of Set 1 | colonia
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | brookings
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | darab
# Processing Record 8 of Set 1 | nuuk
# Processing Record 9 of Set 1 | bilibino
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | haiku-pauwela
# Processing Record 12 of Set 1 | mount gambier
# Processing Record 13 of Set 1 | chibougamau
# Processing Record 14 of Set 1 | koryazhma
# Processing Record 15 of Set 1 | aflou
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | utrik
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | yaren
# Processing Record 21 of Set 1 | eastham
# Processing Record 22 of Set 1 | kalmunai
# Processing Record 23 of Set 1 | puerto natales
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | stanley
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | crane
# Processing Record 29 of Set 1 | nova vicosa
# Processing Record 30 of Set 1 | adamstown
# Processing Record 31 of Set 1 | zag
# Processing Record 32 of Set 1 | flying fish cove
# Processing Record 33 of Set 1 | kaohsiung
# Processing Record 34 of Set 1 | praya
# Processing Record 35 of Set 1 | atafu village
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | howard springs
# Processing Record 38 of Set 1 | margaret river
# Processing Record 39 of Set 1 | isafjordur
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | golmarmara
# Processing Record 45 of Set 1 | ebon
# Processing Record 46 of Set 1 | glace bay
# Processing Record 47 of Set 1 | blackmans bay
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | pokachi
# Processing Record 0 of Set 2 | yuzhno-kurilsk
# Processing Record 1 of Set 2 | edinburgh of the seven seas
# Processing Record 2 of Set 2 | debre tabor
# Processing Record 3 of Set 2 | chiredzi
# Processing Record 4 of Set 2 | fisterra
# Processing Record 5 of Set 2 | kavaratti
# Processing Record 6 of Set 2 | cabo san lucas
# Processing Record 7 of Set 2 | nar'yan-mar
# Processing Record 8 of Set 2 | i-n-salah
# Processing Record 9 of Set 2 | mandvi
# Processing Record 10 of Set 2 | kapuskasing
# Processing Record 11 of Set 2 | tual
# Processing Record 12 of Set 2 | mikuni
# Processing Record 13 of Set 2 | grytviken
# Processing Record 14 of Set 2 | ngawi
# Processing Record 15 of Set 2 | karachi
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | erenhot
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | sabang
# Processing Record 21 of Set 2 | veraval
# Processing Record 22 of Set 2 | manaure
# Processing Record 23 of Set 2 | ola
# Processing Record 24 of Set 2 | noyabrsk
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | ocean shores
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | auki
# Processing Record 29 of Set 2 | vorkuta
# Processing Record 30 of Set 2 | saltillo
# Processing Record 31 of Set 2 | daru
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | cidade velha
# Processing Record 34 of Set 2 | labrador city
# Processing Record 35 of Set 2 | tanjung selor
# City not found. Skipping...
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | ulsteinvik
# Processing Record 38 of Set 2 | uturoa
# Processing Record 39 of Set 2 | port mathurin
# Processing Record 40 of Set 2 | keflavik
# Processing Record 41 of Set 2 | itanhem
# Processing Record 42 of Set 2 | maintirano
# Processing Record 43 of Set 2 | lashio
# Processing Record 44 of Set 2 | juba
# Processing Record 45 of Set 2 | mehtar lam
# Processing Record 46 of Set 2 | laguna
# Processing Record 47 of Set 2 | kill devil hills
# Processing Record 48 of Set 2 | qaqortoq
# Processing Record 49 of Set 2 | tafuna
# Processing Record 0 of Set 3 | la paz
# Processing Record 1 of Set 3 | mamuju
# Processing Record 2 of Set 3 | callao
# Processing Record 3 of Set 3 | nova sintra
# Processing Record 4 of Set 3 | kaintragarh
# Processing Record 5 of Set 3 | margate
# Processing Record 6 of Set 3 | soure
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | dudinka
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | el haouaria
# Processing Record 12 of Set 3 | kisumu
# Processing Record 13 of Set 3 | olonkinbyen
# Processing Record 14 of Set 3 | banda aceh
# Processing Record 15 of Set 3 | ovruch
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | iskateley
# Processing Record 18 of Set 3 | mandalgovi
# Processing Record 19 of Set 3 | port macquarie
# Processing Record 20 of Set 3 | ust-nera
# Processing Record 21 of Set 3 | santa maria
# Processing Record 22 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | kiunga
# Processing Record 25 of Set 3 | chonchi
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | thunder bay
# Processing Record 28 of Set 3 | constantia
# Processing Record 29 of Set 3 | racalmuto
# Processing Record 30 of Set 3 | invercargill
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | zhezqazghan
# Processing Record 33 of Set 3 | west island
# Processing Record 34 of Set 3 | hilo
# Processing Record 35 of Set 3 | greenland
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | egilsstadir
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | saipan
# Processing Record 40 of Set 3 | sao vicente
# Processing Record 41 of Set 3 | nago
# Processing Record 42 of Set 3 | fort wellington
# Processing Record 43 of Set 3 | mount isa
# Processing Record 44 of Set 3 | as suwayrah
# Processing Record 45 of Set 3 | manado
# Processing Record 46 of Set 3 | tallulah
# Processing Record 47 of Set 3 | howrah
# Processing Record 48 of Set 3 | papatowai
# Processing Record 49 of Set 3 | novodvinsk
# Processing Record 0 of Set 4 | whitehorse
# Processing Record 1 of Set 4 | dryden
# Processing Record 2 of Set 4 | bel ombre
# Processing Record 3 of Set 4 | anadyr
# Processing Record 4 of Set 4 | grajau
# Processing Record 5 of Set 4 | la passe
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | khvansar
# Processing Record 8 of Set 4 | revda
# Processing Record 9 of Set 4 | una
# Processing Record 10 of Set 4 | rio grande
# Processing Record 11 of Set 4 | georgetown
# Processing Record 12 of Set 4 | bargara
# City not found. Skipping...
# Processing Record 13 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 4 | tokat
# Processing Record 15 of Set 4 | beloyarskiy
# Processing Record 16 of Set 4 | afaahiti
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | west bay
# Processing Record 19 of Set 4 | aasiaat
# Processing Record 20 of Set 4 | san antonio de pale
# Processing Record 21 of Set 4 | lazaro cardenas
# Processing Record 22 of Set 4 | klyuchi
# Processing Record 23 of Set 4 | cannonvale
# Processing Record 24 of Set 4 | ostersund
# Processing Record 25 of Set 4 | vadso
# Processing Record 26 of Set 4 | forster
# Processing Record 27 of Set 4 | nishinoomote
# Processing Record 28 of Set 4 | mariehamn
# Processing Record 29 of Set 4 | tucumcari
# Processing Record 30 of Set 4 | badger
# Processing Record 31 of Set 4 | sonqor
# Processing Record 32 of Set 4 | holualoa
# Processing Record 33 of Set 4 | vinhais
# Processing Record 34 of Set 4 | montehermoso
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | vilyuchinsk
# Processing Record 37 of Set 4 | vorgashor
# Processing Record 38 of Set 4 | polyarnyy
# Processing Record 39 of Set 4 | tura
# Processing Record 40 of Set 4 | pionerskiy
# Processing Record 41 of Set 4 | hermanus
# Processing Record 42 of Set 4 | raduzhny
# Processing Record 43 of Set 4 | tlanchinol
# Processing Record 44 of Set 4 | arteche
# Processing Record 45 of Set 4 | mangalore
# Processing Record 46 of Set 4 | lihue
# Processing Record 47 of Set 4 | merizo village
# Processing Record 48 of Set 4 | saint-pierre
# Processing Record 49 of Set 4 | saint-louis
# Processing Record 0 of Set 5 | beberibe
# Processing Record 1 of Set 5 | igarka
# Processing Record 2 of Set 5 | kalaoa
# Processing Record 3 of Set 5 | licheng
# Processing Record 4 of Set 5 | san luis de la loma
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 7 of Set 5 | sotik post
# Processing Record 8 of Set 5 | emerald
# Processing Record 9 of Set 5 | wailua homesteads
# Processing Record 10 of Set 5 | warrnambool
# Processing Record 11 of Set 5 | shahapur
# Processing Record 12 of Set 5 | ulan-ude
# Processing Record 13 of Set 5 | balkashino
# Processing Record 14 of Set 5 | shiqian
# Processing Record 15 of Set 5 | khovd
# Processing Record 16 of Set 5 | itacare
# Processing Record 17 of Set 5 | safi
# Processing Record 18 of Set 5 | prado
# Processing Record 19 of Set 5 | preobrazheniye
# Processing Record 20 of Set 5 | katsuren-haebaru
# Processing Record 21 of Set 5 | udachny
# Processing Record 22 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 5 | muisne
# Processing Record 24 of Set 5 | nantucket
# Processing Record 25 of Set 5 | lezhe
# Processing Record 26 of Set 5 | plettenberg bay
# Processing Record 27 of Set 5 | gizo
# Processing Record 28 of Set 5 | mancio lima
# Processing Record 29 of Set 5 | kalevala
# Processing Record 30 of Set 5 | ataq
# Processing Record 31 of Set 5 | kenai
# Processing Record 32 of Set 5 | ghadamis
# Processing Record 33 of Set 5 | summerside
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 36 of Set 5 | luorong
# Processing Record 37 of Set 5 | alice town
# Processing Record 38 of Set 5 | yaring
# Processing Record 39 of Set 5 | richards bay
# Processing Record 40 of Set 5 | terrace
# Processing Record 41 of Set 5 | vangaindrano
# Processing Record 42 of Set 5 | hawaiian paradise park
# Processing Record 43 of Set 5 | whakatane
# Processing Record 44 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 5 | conceicao do mato dentro
# Processing Record 46 of Set 5 | port moresby
# Processing Record 47 of Set 5 | ulladulla
# Processing Record 48 of Set 5 | puerto baquerizo moreno
# Processing Record 49 of Set 5 | vila franca do campo
# Processing Record 0 of Set 6 | mucuri
# Processing Record 1 of Set 6 | enewetak
# Processing Record 2 of Set 6 | berezovyy
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | sisimiut
# Processing Record 5 of Set 6 | opuwo
# Processing Record 6 of Set 6 | olgii
# City not found. Skipping...
# Processing Record 7 of Set 6 | fale old settlement
# Processing Record 8 of Set 6 | pechora
# Processing Record 9 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 10 of Set 6 | ambodifotatra
# Processing Record 11 of Set 6 | dunedin
# Processing Record 12 of Set 6 | priargunsk
# Processing Record 13 of Set 6 | tamanrasset
# Processing Record 14 of Set 6 | valparaiso
# Processing Record 15 of Set 6 | pasighat
# Processing Record 16 of Set 6 | horta
# Processing Record 17 of Set 6 | ketchikan
# Processing Record 18 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 19 of Set 6 | varberg
# Processing Record 20 of Set 6 | carutapera
# Processing Record 21 of Set 6 | rapar
# Processing Record 22 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 23 of Set 6 | ukholovo
# Processing Record 24 of Set 6 | kilmore
# Processing Record 25 of Set 6 | cadale
# Processing Record 26 of Set 6 | huaicheng
# Processing Record 27 of Set 6 | hadibu
# Processing Record 28 of Set 6 | marsa alam
# Processing Record 29 of Set 6 | chake chake
# Processing Record 30 of Set 6 | trondheim
# Processing Record 31 of Set 6 | kabwe
# Processing Record 32 of Set 6 | willowmore
# Processing Record 33 of Set 6 | eirunepe
# Processing Record 34 of Set 6 | hashtrud
# Processing Record 35 of Set 6 | black river
# Processing Record 36 of Set 6 | selfoss
# Processing Record 37 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 38 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 39 of Set 6 | svetlyy
# Processing Record 40 of Set 6 | kingston
# Processing Record 41 of Set 6 | obo
# Processing Record 42 of Set 6 | totness
# Processing Record 43 of Set 6 | qui nhon
# Processing Record 44 of Set 6 | kovdor
# Processing Record 45 of Set 6 | papao
# Processing Record 46 of Set 6 | svalyava
# Processing Record 47 of Set 6 | bandarbeyla
# Processing Record 48 of Set 6 | ust-tsilma
# Processing Record 49 of Set 6 | natal
# Processing Record 0 of Set 7 | st. john's
# Processing Record 1 of Set 7 | parintins
# Processing Record 2 of Set 7 | queenstown
# Processing Record 3 of Set 7 | remire-montjoly
# Processing Record 4 of Set 7 | la'ie
# Processing Record 5 of Set 7 | senanga
# Processing Record 6 of Set 7 | port augusta
# Processing Record 7 of Set 7 | aitape
# Processing Record 8 of Set 7 | saudarkrokur
# Processing Record 9 of Set 7 | santa rosalia
# Processing Record 10 of Set 7 | zouerate
# Processing Record 11 of Set 7 | waddan
# Processing Record 12 of Set 7 | swan hill
# Processing Record 13 of Set 7 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 14 of Set 7 | chernyshevskiy
# Processing Record 15 of Set 7 | port elizabeth
# Processing Record 16 of Set 7 | port-vila
# Processing Record 17 of Set 7 | cartagena
# Processing Record 18 of Set 7 | kununurra
# Processing Record 19 of Set 7 | laredo
# Processing Record 20 of Set 7 | walvis bay
# Processing Record 21 of Set 7 | nyborg
# Processing Record 22 of Set 7 | jamestown
# Processing Record 23 of Set 7 | ad dawadimi
# Processing Record 24 of Set 7 | bodo
# Processing Record 25 of Set 7 | onega
# Processing Record 26 of Set 7 | namibe
# Processing Record 27 of Set 7 | carnarvon
# Processing Record 28 of Set 7 | ta`u
# Processing Record 29 of Set 7 | drayton valley
# Processing Record 30 of Set 7 | secunda
# Processing Record 31 of Set 7 | lubang
# Processing Record 32 of Set 7 | saint-joseph
# Processing Record 33 of Set 7 | zyrardow
# Processing Record 34 of Set 7 | mirpur sakro
# Processing Record 35 of Set 7 | ilulissat
# Processing Record 36 of Set 7 | sur
# Processing Record 37 of Set 7 | espanola
# Processing Record 38 of Set 7 | tazacorte
# Processing Record 39 of Set 7 | baardheere
# Processing Record 40 of Set 7 | santa terezinha
# Processing Record 41 of Set 7 | baihar
# Processing Record 42 of Set 7 | las tablas
# Processing Record 43 of Set 7 | rahim yar khan
# City not found. Skipping...
# Processing Record 44 of Set 7 | port lincoln
# Processing Record 45 of Set 7 | usinsk
# Processing Record 46 of Set 7 | vila velha
# Processing Record 47 of Set 7 | grand-popo
# Processing Record 48 of Set 7 | damghan
# Processing Record 49 of Set 7 | homer
# Processing Record 0 of Set 8 | cumaral
# Processing Record 1 of Set 8 | pacific grove
# Processing Record 2 of Set 8 | kimbe
# Processing Record 3 of Set 8 | san mariano
# Processing Record 4 of Set 8 | torghay
# Processing Record 5 of Set 8 | thinadhoo
# Processing Record 6 of Set 8 | taoudenni
# Processing Record 7 of Set 8 | vesele
# Processing Record 8 of Set 8 | jiangkou
# Processing Record 9 of Set 8 | yelizovo
# Processing Record 10 of Set 8 | silvi
# Processing Record 11 of Set 8 | bathsheba
# Processing Record 12 of Set 8 | minot air force base
# Processing Record 13 of Set 8 | itoman
# Processing Record 14 of Set 8 | berghem
# Processing Record 15 of Set 8 | sofifi
# City not found. Skipping...
# Processing Record 16 of Set 8 | kaura namoda
# Processing Record 17 of Set 8 | taroa
# Processing Record 18 of Set 8 | moyale
# Processing Record 19 of Set 8 | susuman
# Processing Record 20 of Set 8 | tchintabaraden
# Processing Record 21 of Set 8 | chaparral
# Processing Record 22 of Set 8 | antsiranana
# Processing Record 23 of Set 8 | mar del plata
# Processing Record 24 of Set 8 | al jawf
# Processing Record 25 of Set 8 | shiguai
# Processing Record 26 of Set 8 | zhukovka
# Processing Record 27 of Set 8 | bumba
# Processing Record 28 of Set 8 | siliguri
# Processing Record 29 of Set 8 | tazovsky
# Processing Record 30 of Set 8 | viedma
# Processing Record 31 of Set 8 | liuhe
# Processing Record 32 of Set 8 | puerto el triunfo
# Processing Record 33 of Set 8 | toliara
# Processing Record 34 of Set 8 | mabopane
# Processing Record 35 of Set 8 | nuku'alofa
# Processing Record 36 of Set 8 | mili
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | lira
# Processing Record 39 of Set 8 | urangan
# Processing Record 40 of Set 8 | sola
# Processing Record 41 of Set 8 | camacupa
# Processing Record 42 of Set 8 | san jose de guanipa
# Processing Record 43 of Set 8 | kinkala
# Processing Record 44 of Set 8 | grand falls-windsor
# Processing Record 45 of Set 8 | yeppoon
# Processing Record 46 of Set 8 | palmer
# Processing Record 47 of Set 8 | bardai
# Processing Record 48 of Set 8 | alofi
# Processing Record 49 of Set 8 | dwarka
# Processing Record 0 of Set 9 | port saint john's
# Processing Record 1 of Set 9 | pangody
# Processing Record 2 of Set 9 | tocopilla
# Processing Record 3 of Set 9 | bodaybo
# Processing Record 4 of Set 9 | mahina
# Processing Record 5 of Set 9 | sinabang
# Processing Record 6 of Set 9 | 'ain deheb
# Processing Record 7 of Set 9 | trenggalek
# Processing Record 8 of Set 9 | manas
# Processing Record 9 of Set 9 | colipapa
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | ilebo
# Processing Record 12 of Set 9 | swakopmund
# Processing Record 13 of Set 9 | basco
# Processing Record 14 of Set 9 | fort bragg
# Processing Record 15 of Set 9 | mersing
# Processing Record 16 of Set 9 | guatire
# Processing Record 17 of Set 9 | tabou
# Processing Record 18 of Set 9 | bay harbor
# Processing Record 19 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 20 of Set 9 | monaragala
# Processing Record 21 of Set 9 | lepsy
# Processing Record 22 of Set 9 | olyokminsk
# Processing Record 23 of Set 9 | bamboo flat
# Processing Record 24 of Set 9 | san patricio
# Processing Record 25 of Set 9 | leninskoye
# Processing Record 26 of Set 9 | pinarbasi
# Processing Record 27 of Set 9 | solnechnyy
# Processing Record 28 of Set 9 | makhambet
# Processing Record 29 of Set 9 | taro
# Processing Record 30 of Set 9 | bac lieu
# Processing Record 31 of Set 9 | touros
# Processing Record 32 of Set 9 | klaksvik
# Processing Record 33 of Set 9 | adam
# Processing Record 34 of Set 9 | newman
# Processing Record 35 of Set 9 | verkhneyarkeyevo
# Processing Record 36 of Set 9 | sievi
# Processing Record 37 of Set 9 | kristiansund
# Processing Record 38 of Set 9 | vilyuysk
# Processing Record 39 of Set 9 | mandera
# Processing Record 40 of Set 9 | paita
# Processing Record 41 of Set 9 | blackwater
# Processing Record 42 of Set 9 | bontang
# Processing Record 43 of Set 9 | weno
# Processing Record 44 of Set 9 | beaufort west
# Processing Record 45 of Set 9 | dostpur
# Processing Record 46 of Set 9 | hardys memories of africa
# City not found. Skipping...
# Processing Record 47 of Set 9 | alice springs
# Processing Record 48 of Set 9 | tamandare
# Processing Record 49 of Set 9 | kolwezi
# Processing Record 0 of Set 10 | suva
# Processing Record 1 of Set 10 | kimberley
# Processing Record 2 of Set 10 | abraham's bay
# City not found. Skipping...
# Processing Record 3 of Set 10 | palmas de monte alto
# Processing Record 4 of Set 10 | rongelap
# Processing Record 5 of Set 10 | aykhal
# Processing Record 6 of Set 10 | kholmsk
# Processing Record 7 of Set 10 | betio village
# Processing Record 8 of Set 10 | macusani
# Processing Record 9 of Set 10 | sinop
# Processing Record 10 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 11 of Set 10 | bikenibeu village
# Processing Record 12 of Set 10 | sao gabriel da cachoeira
# Processing Record 13 of Set 10 | mariental
# Processing Record 14 of Set 10 | jianshui
# Processing Record 15 of Set 10 | malango
# Processing Record 16 of Set 10 | tanjung pandan
# Processing Record 17 of Set 10 | bonham
# Processing Record 18 of Set 10 | achinsk
# Processing Record 19 of Set 10 | batangafo
# Processing Record 20 of Set 10 | xuchang
# Processing Record 21 of Set 10 | conceicao da barra
# Processing Record 22 of Set 10 | karratha
# Processing Record 23 of Set 10 | la ronge
# Processing Record 24 of Set 10 | itaituba
# Processing Record 25 of Set 10 | broken hill
# Processing Record 26 of Set 10 | quatre cocos
# Processing Record 27 of Set 10 | tolanaro
# Processing Record 28 of Set 10 | vuyyuru
# Processing Record 29 of Set 10 | zeya
# Processing Record 30 of Set 10 | villa gesell
# Processing Record 31 of Set 10 | thanh pho uong bi
# Processing Record 32 of Set 10 | prabumulih
# Processing Record 33 of Set 10 | el calafate
# Processing Record 34 of Set 10 | qarazhal
# Processing Record 35 of Set 10 | ko pha ngan
# Processing Record 36 of Set 10 | antofagasta
# Processing Record 37 of Set 10 | kurtamysh
# Processing Record 38 of Set 10 | holbrook
# Processing Record 39 of Set 10 | mollendo
# Processing Record 40 of Set 10 | kayangel
# Processing Record 41 of Set 10 | awjilah
# Processing Record 42 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 43 of Set 10 | balapur
# Processing Record 44 of Set 10 | akureyri
# Processing Record 45 of Set 10 | nikolayevsk-on-amure
# Processing Record 46 of Set 10 | ballina
# Processing Record 47 of Set 10 | port douglas
# Processing Record 48 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 49 of Set 10 | souillac
# Processing Record 0 of Set 11 | mount pearl
# Processing Record 1 of Set 11 | raj-nandgaon
# Processing Record 2 of Set 11 | premia de mar
# Processing Record 3 of Set 11 | nathdwara
# Processing Record 4 of Set 11 | roxas
# Processing Record 5 of Set 11 | lorengau
# Processing Record 6 of Set 11 | mangai
# Processing Record 7 of Set 11 | dalbandin
# Processing Record 8 of Set 11 | kostroma
# Processing Record 9 of Set 11 | genhe
# Processing Record 10 of Set 11 | hotan
# Processing Record 11 of Set 11 | sao jose da coroa grande
# Processing Record 12 of Set 11 | berdigestyakh
# Processing Record 13 of Set 11 | pennathur
# Processing Record 14 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 15 of Set 11 | ivdel'
# Processing Record 16 of Set 11 | gaspe
# Processing Record 17 of Set 11 | ndjole
# Processing Record 18 of Set 11 | kismayo
# Processing Record 19 of Set 11 | cao bang
# Processing Record 20 of Set 11 | pleasanton
# Processing Record 21 of Set 11 | noumea
# Processing Record 22 of Set 11 | inhambane
# Processing Record 23 of Set 11 | krasnozerskoye
# Processing Record 24 of Set 11 | shingu
# Processing Record 25 of Set 11 | nadym
# Processing Record 26 of Set 11 | oualidia
# City not found. Skipping...
# Processing Record 27 of Set 11 | narasannapeta
# Processing Record 28 of Set 11 | cambria
# Processing Record 29 of Set 11 | hovd
# Processing Record 30 of Set 11 | evanston
# Processing Record 31 of Set 11 | robit
# Processing Record 32 of Set 11 | kirakira
# Processing Record 33 of Set 11 | lander
# Processing Record 34 of Set 11 | viana do castelo
# Processing Record 35 of Set 11 | dange
# Processing Record 36 of Set 11 | island harbour
# Processing Record 37 of Set 11 | tsiombe
# Processing Record 38 of Set 11 | laojunmiao
# Processing Record 39 of Set 11 | boda
# Processing Record 40 of Set 11 | gadzhiyevo
# Processing Record 41 of Set 11 | kodok
# City not found. Skipping...
# Processing Record 42 of Set 11 | chaplynka
# Processing Record 43 of Set 11 | vammala
# Processing Record 44 of Set 11 | shalya
# Processing Record 45 of Set 11 | kotri
# Processing Record 46 of Set 11 | hobyo
# Processing Record 47 of Set 11 | arenapolis
# Processing Record 48 of Set 11 | rabo de peixe
# Processing Record 49 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 0 of Set 12 | mugia
# Processing Record 1 of Set 12 | bafra
# Processing Record 2 of Set 12 | sydney
# Processing Record 3 of Set 12 | puerto carreno
# Processing Record 4 of Set 12 | ozalp
# Processing Record 5 of Set 12 | syktyvkar
# Processing Record 6 of Set 12 | paphos
# Processing Record 7 of Set 12 | saratamata
# City not found. Skipping...
# Processing Record 8 of Set 12 | al hilaliyya
# Processing Record 9 of Set 12 | trevelin
# Processing Record 10 of Set 12 | birjand
# Processing Record 11 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 12 of Set 12 | fauske
# Processing Record 13 of Set 12 | kirensk
# Processing Record 14 of Set 12 | togur
# Processing Record 15 of Set 12 | levuka
# Processing Record 16 of Set 12 | siwa oasis
# Processing Record 17 of Set 12 | ha tien
# Processing Record 18 of Set 12 | masterton
# Processing Record 19 of Set 12 | ouellah
# City not found. Skipping...
# Processing Record 20 of Set 12 | askoy
# Processing Record 21 of Set 12 | kiama
# Processing Record 22 of Set 12 | baillif
# Processing Record 23 of Set 12 | notodden
# Processing Record 24 of Set 12 | eydhafushi
# Processing Record 25 of Set 12 | dazhou
# Processing Record 26 of Set 12 | el granada
# Processing Record 27 of Set 12 | babina
# Processing Record 28 of Set 12 | pyhaselka
# Processing Record 29 of Set 12 | okha
# Processing Record 30 of Set 12 | sao pedro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(country_list))
# Out:
# 551

# %%
# Convert the cities weather data into a Pandas DataFrame
weather_df = {
    "City": city_list,
    "Lat": lat_list,
    "Lng": lng_list,
    "Max Temp": max_temp_list,
    "Humidity": humidity_list,
    "Cloudiness": cloudiness_list,
    "Wind Speed": windspeed_list,
    "Country": country_list,
    "Date": date_list}

# Create a DataFrame
weather_dict = pd.DataFrame(weather_df)
weather_dict
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kutum  14.2000   24.6667     12.56        23           6
# 1         Nogliki  51.8333  143.1667    -14.81        77           3
# 2         Cologne  50.9333    6.9500     12.12        81         100
# 3    Punta Arenas -53.1500  -70.9167     21.06        40          75
# 4       Brookings  44.3114  -96.7984      1.00        95         100
# ..            ...      ...       ...       ...       ...         ...
# 546    El Granada  37.5027 -122.4694     13.88        87         100
# 547        Babīna  25.2500   78.4667     15.27        93          51
# 548     Pyhäselkä  62.4333   29.9667     -3.67        97          98
# 549          Okha  53.5739  142.9478    -19.47        90          21
# 550     São Pedro -22.5486  -47.9139     20.82        71          98
#
#      Wind Speed Country        Date
# 0          4.08      SD  1707100049
# 1          4.02      RU  1707099861
# 2          9.77      DE  1707099851
# 3         11.32      CL  1707099733
# 4          3.09      US  1707099759
# ..          ...     ...         ...
# 546        9.26      US  1707100126
# 547        1.79      IN  1707100126
# 548        0.88      FI  1707100126
# 549        6.78      RU  1707100126
# 550        1.15      BR  1707100126
#
# [551 rows x 9 columns]

# %%
# Show Record Count
weather_dict.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %%
# Export the City_Data into a csv
weather_dict.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               Kutum  14.2000   24.6667     12.56        23           6
# 1             Nogliki  51.8333  143.1667    -14.81        77           3
# 2             Cologne  50.9333    6.9500     12.12        81         100
# 3        Punta Arenas -53.1500  -70.9167     21.06        40          75
# 4           Brookings  44.3114  -96.7984      1.00        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.08      SD  1707100049
# 1              4.02      RU  1707099861
# 2              9.77      DE  1707099851
# 3             11.32      CL  1707099733
# 4              3.09      US  1707099759

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
weather_dict.plot(kind = 'scatter', x=["Lat"], y=["Max Temp"], grid=True, figsize=(8,8), edgecolor="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Latitude vs. Temperature 2/3/2024")

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
weather_dict.plot(kind = 'scatter', x=["Lat"], y=["Humidity"], grid=True, figsize=(8,8), edgecolor="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs. Humidity 2/3/2024")

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
weather_dict.plot(kind = 'scatter', x=["Lat"], y=["Cloudiness"], grid=True, figsize=(8,8), edgecolor="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs. Cloudiness 2/3/2024")

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
weather_dict.plot(kind = 'scatter', x=["Lat"], y=["Wind Speed"], grid=True, figsize=(8,8), edgecolor="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs. Wind Speed 2/3/2023")

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y, xlabel='X-axis', ylabel='Y-axis', title='Linear Regression Plot'):
    
    # Reshape the data for scikit-learn if it's a single feature
    x = np.array(x).reshape(-1, 1)

    # Create a linear regression model
    model = LinearRegression()
    model.fit(x, y)

    # Plot the data points
    plt.figure(figsize=(8, 6))
    plt.scatterplot(x=x.flatten(), y=y, color='blue', label='Data Points')

    # Plot the regression line
    plt.annotate(x=x.flatten(), y=model.predict(x), color='red', label='Linear Regression Line')

    # Customize plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = weather_dict[city_data_df["Lat"]>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kutum  14.2000   24.6667     12.56        23           6        4.08
# 1    Nogliki  51.8333  143.1667    -14.81        77           3        4.02
# 2    Cologne  50.9333    6.9500     12.12        81         100        9.77
# 4  Brookings  44.3114  -96.7984      1.00        95         100        3.09
# 6      Dārāb  28.7519   54.5444      4.76        36          15        0.73
#
#   Country        Date
# 0      SD  1707100049
# 1      RU  1707099861
# 2      DE  1707099851
# 4      US  1707099759
# 6      IR  1707099868

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = weather_dict[city_data_df["Lat"]< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3        Punta Arenas -53.1500  -70.9167     21.06        40          75
# 5   Port-aux-Français -49.3500   70.2167      5.44        72          36
# 9            Waitangi -43.9535 -176.5597     16.60        80          66
# 11      Mount Gambier -37.8333  140.7667     19.67        45          57
# 17         Bredasdorp -34.5322   20.0403     21.04        89          10
#
#     Wind Speed Country        Date
# 3        11.32      CL  1707099733
# 5         9.72      TF  1707099818
# 9         5.54      NZ  1707099818
# 11        5.20      AU  1707099823
# 17        1.24      ZA  1707099831

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.ylabel('Max Temperature', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(0, -300), fontsize=10, color='darkred')


# Set the limits of the y axis:
plt.ylim(min(weather_dict['Max Temp'])-10, max(weather_dict['Max Temp'])+10)

# Set the limits of the x axis:
plt.xlim(-3, max(weather_dict['Lat'])+3)

# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)


# Show plot:
plt.show()

plt.savefig("Northern Hemisphere - Max Temp vs. Latitude.png")
# Out:
# The r-value is: -0.8839761735611371.

# %% [markdown]
# **Discussion about the linear relationship:** This graph shows a negative regression between latitude and Max Temperautre. With the r value being a negative value, this shows a negative correlation bewteen what is being plotted. The further north the cities are located, the max temperature will rise.

# %%
# Linear regression on Southern Hemisphere
t_values = southern_hemi_df['Lat']
v_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(t_values, v_values)

regress_values = t_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.ylabel('Max Temperature', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(-50, 35),fontsize=10, color='darkred')

# Create plot:
plt.scatter(t_values, v_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(t_values,regress_values, 'darkred', linewidth=2)

# print rvalue
print(f"The r-value is: {rvalue}.")


# Show plot:
plt.show()

plt.savefig("Southern Hemisphere - Max Temp vs. Latitude.png")
# Out:
# The r-value is: 0.374209801690556.

# %% [markdown]
# **Discussion about the linear relationship:** The Southern scatter plot show a positive correlation. This shows when the latitude decreases, the temperature rise. Both graphs shows that the r value is postitve whech show that the correlation is postive, also.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
a_values = northern_hemi_df['Lat']
b_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(a_values, b_values)

regress_values = a_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity vs. Latitude')
plt.ylabel('Humidity', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(51,6), fontsize=10, color='darkred')

# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(a_values,b_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(a_values,regress_values,'darkred', linewidth=2)


# Show plot:
plt.show()

plt.savefig("Northern Hemisphere - Humidity vs. Latitude.png")
# Out:
# The r-value is: 0.3902146817380271.

# %%
# Southern Hemisphere
a_values = southern_hemi_df['Lat']
b_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(a_values, b_values)

regress_values = a_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity vs. Latitude')
plt.ylabel('Humidity', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(51,6), fontsize=10, color='darkred')


# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(a_values,b_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(a_values,regress_values,'darkred', linewidth=2)


# Show plot:
plt.show()
# Out:
# The r-value is: 0.39231806302822386.

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and humidity. Both graphs show the cities spread out sporadically.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
c_values = northern_hemi_df['Lat']
d_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(c_values, d_values)

regress_values = c_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness vs. Latitude')
plt.ylabel('Cloudiness', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(40, 35), fontsize=10, color='darkred')

# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(c_values,d_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(c_values,regress_values,'darkred', linewidth=2)


# Show plot:
plt.show()

plt.savefig("Northern Hemisphere - Cloudiness vs. Latitude.png")
# Out:
# The r-value is: 0.22435461220292166.

# %%
# Southern Hemisphere
e_values = southern_hemi_df['Lat']
f_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(e_values, f_values)

regress_values = e_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness vs. Latitude')
plt.ylabel('Cloudiness', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(-50, 80), fontsize=10, color='darkred')

# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(e_values,f_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(e_values,regress_values,'darkred', linewidth=2)


# Show plot:
plt.show()

plt.savefig("Southern Hemisphere - Cloudiness vs. Latitude.png")
# Out:
# The r-value is: 0.31355265968909746.

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlaton between latitude and cloudiness. All cities are spread out throughout both graph.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
p_values = northern_hemi_df['Lat']
q_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(p_values, q_values)

regress_values = p_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude')
plt.ylabel('Wind Speed', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(40, 35), fontsize=10, color='darkred')

# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(p_values,q_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(p_values,regress_values,'darkred', linewidth=2)


# Show plot:
plt.show()

plt.savefig("Northern Hemisphere - Wind Speed vs. Latitude.png")
# Out:
# The r-value is: -0.03424174939474846.

# %%
# Southern Hemisphere
p_values = southern_hemi_df['Lat']
q_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(p_values, q_values)

regress_values = p_values * slope + intercept

line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude')
plt.ylabel('Wind Speed', color='black')
plt.xlabel('Latitude', color='black')
plt.annotate(line_eq,(-20, 20), fontsize=10, color='darkred')

# print rvalue
print(f"The r-value is: {rvalue}.")

# Create plot:
plt.scatter(p_values,q_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(p_values,regress_values,'darkred', linewidth=2)


# Set the limits of the y axis:
plt.ylim(-1, 25)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Show plot:
plt.show()

plt.savefig("Southern Hemisphere - Wind Speed vs. Latitude.png")
# Out:
# The r-value is: -0.3091494696329268.

# %% [markdown]
# **Discussion about the linear relationship:** There is a slight negative corelation between latitude and wind speed. Both graph show a slight relationship between what is being graphed.
